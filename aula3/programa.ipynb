# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('dados/10-08-2023_NEGOCIOSAVISTA.txt',header=0,sep=';', decimal=',')

# %%
df1.head(5)
# Out:
#   DataReferencia CodigoInstrumento  AcaoAtualizacao  PrecoNegocio  \
# 0     2023-08-10            WSPU23                0       4505.50
# 1     2023-08-10            BGIV23                0        224.00
# 2     2023-08-10            ISPU23                0       4507.50
# 3     2023-08-10            DI1F24                0         12.46
# 4     2023-08-10            BGIV23                0        222.65
#
#    QuantidadeNegociada  HoraFechamento  CodigoIdentificadorNegocio  \
# 0                    1        90000007                          10
# 1                    1        90000020                         290
# 2                    5        90000957                          10
# 3                   25        90006853                          10
# 4                    1        90011923                         300
#
#    TipoSessaoPregao DataNegocio  CodigoParticipanteComprador  \
# 0                 1  2023-08-10                        120.0
# ...
